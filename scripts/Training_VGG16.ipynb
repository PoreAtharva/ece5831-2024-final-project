# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import preprocess_input

# Directory paths for real and deepfake images
train_dir = 'C:/Users/ksaks/Downloads/DATA/Training/train'  # Directory containing 'real' and 'deepfake' folders
val_dir = r'C:\Users\ksaks\Downloads\DATA\Training\VAL'  # Directory containing 'real' and 'deepfake' folders

# Set up image data generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,  # Rescale image pixel values to [0, 1]
    rotation_range=20,  # Rotate images randomly within a range
    width_shift_range=0.2,  # Randomly shift images horizontally
    height_shift_range=0.2,  # Randomly shift images vertically
    shear_range=0.2,  # Randomly apply shearing transformations
    zoom_range=0.2,  # Randomly zoom in or out on the images
    horizontal_flip=True,  # Randomly flip the images horizontally
    fill_mode='nearest'  # Fill in missing pixels after transformation
)

val_datagen = ImageDataGenerator(rescale=1.0/255.0)  # Validation data is just rescaled

# Load images from directories and apply the above transformations
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),  # Resize images to 224x224
    batch_size=32,  # Batch size
    class_mode='binary'  # Binary classification (real vs deepfake)
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),  # Resize images to 224x224
    batch_size=32,  # Batch size
    class_mode='binary'  # Binary classification (real vs deepfake)
)
# Out:
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 4812 images belonging to 2 classes.
# Found 2068 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import TensorBoard
import os

# Load the VGG16 model with pre-trained weights (ImageNet)
# We exclude the top layers because we will add our own output layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


# Add custom layers on top of VGG16 for our classification task
model = models.Sequential([
    base_model,  # Add the VGG16 base model
    layers.Flatten(),  # Flatten the output from the base model
    layers.Dense(256, activation='relu'),  # Add a dense layer with ReLU activation
    layers.Dense(1, activation='sigmoid')  # Output layer with sigmoid activation (binary classification)
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Summary of the model architecture
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 6423041 (24.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
import os
from tensorflow.keras.callbacks import Callback

class TopKModelSaver(Callback):
    def __init__(self, directory, monitor='val_loss', k=5, mode='min'):
        super(TopKModelSaver, self).__init__()
        self.directory = directory
        self.monitor = monitor
        self.k = k
        self.mode = mode
        self.top_k_models = []  # List to store top k models' metadata

        # Ensure the directory exists
        os.makedirs(self.directory, exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        current_value = logs.get(self.monitor)
        if current_value is None:
            print(f"Warning: Monitor value '{self.monitor}' is missing in logs.")
            return

        # Determine whether to add the current model
        should_save = False
        if len(self.top_k_models) < self.k:
            should_save = True
        else:
            if self.mode == 'min' and current_value < max(self.top_k_models, key=lambda x: x['value'])['value']:
                should_save = True
            elif self.mode == 'max' and current_value > min(self.top_k_models, key=lambda x: x['value'])['value']:
                should_save = True

        if should_save:
            # Construct the file path
            model_path = os.path.join(self.directory, f'model_epoch_{epoch + 1:02d}-{self.monitor}_{current_value:.4f}.h5')

            # Save the current model
            self.model.save(model_path)

            # Update the top_k_models list
            self.top_k_models.append({'value': current_value, 'path': model_path})
            self.top_k_models = sorted(self.top_k_models, key=lambda x: x['value'], reverse=(self.mode == 'max'))

            # If more than k models, remove the worst
            if len(self.top_k_models) > self.k:
                worst_model = self.top_k_models.pop()
                os.remove(worst_model['path'])  # Delete the file

            print(f"Model saved to {model_path}. Current top {self.k} models:")
            for model_info in self.top_k_models:
                print(f"  - {model_info['path']} (val: {model_info['value']:.4f})")

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard

# Directory to store TensorBoard logs
log_dir = r'C:\Users\ksaks\Downloads\DATA'
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# # Early stopping to monitor validation loss and stop training if it doesn't improve
# early_stopping = EarlyStopping(
#     monitor='val_loss',  # Monitor validation loss
#     patience=5,          # Number of epochs with no improvement after which training will be stopped
#     verbose=1,           # Print updates
#     restore_best_weights=True  # Restore the best weights at the end of training
# )

# Create the TopKModelSaver callback
top_k_saver = TopKModelSaver(
    directory=r'C:\Users\ksaks\Downloads\DATA\Models',
    monitor='val_loss',
    k=20,
    mode='min'  # Change to 'max' if you want to maximize the monitored metric
)

# Train the model with the new callback
history = model.fit(
    train_generator,
    epochs=50,  # Number of epochs
    validation_data=val_generator,
    callbacks=[tensorboard_callback, top_k_saver]  # Include the new callback
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 151/151 [==============================] - ETA: 0s - loss: 0.5541 - accuracy: 0.7943Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 379s 2s/step - loss: 0.5541 - accuracy: 0.7943 - val_loss: 0.8150 - val_accuracy: 0.7205
# Epoch 2/50
# C:\Users\ksaks\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 151/151 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8697Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 378s 3s/step - loss: 0.3445 - accuracy: 0.8697 - val_loss: 0.5823 - val_accuracy: 0.7655
# Epoch 3/50
# 151/151 [==============================] - ETA: 0s - loss: 0.3042 - accuracy: 0.8797Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 374s 2s/step - loss: 0.3042 - accuracy: 0.8797 - val_loss: 0.5981 - val_accuracy: 0.7568
# Epoch 4/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.8892Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 368s 2s/step - loss: 0.2793 - accuracy: 0.8892 - val_loss: 0.6692 - val_accuracy: 0.7500
# Epoch 5/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8915Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 365s 2s/step - loss: 0.2758 - accuracy: 0.8915 - val_loss: 0.6256 - val_accuracy: 0.7577
# Epoch 6/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8948Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2580 - accuracy: 0.8948 - val_loss: 0.5797 - val_accuracy: 0.7471
# Epoch 7/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.8932Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 363s 2s/step - loss: 0.2696 - accuracy: 0.8932 - val_loss: 0.5753 - val_accuracy: 0.7524
# Epoch 8/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9044Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 363s 2s/step - loss: 0.2399 - accuracy: 0.9044 - val_loss: 0.5299 - val_accuracy: 0.7548
# Epoch 9/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.9005Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 365s 2s/step - loss: 0.2412 - accuracy: 0.9005 - val_loss: 0.5340 - val_accuracy: 0.7563
# Epoch 10/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9038Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 362s 2s/step - loss: 0.2337 - accuracy: 0.9038 - val_loss: 0.5617 - val_accuracy: 0.7505
# Epoch 11/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9036Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2307 - accuracy: 0.9036 - val_loss: 0.5401 - val_accuracy: 0.7592
# Epoch 12/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 0.8990Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2358 - accuracy: 0.8990 - val_loss: 0.5177 - val_accuracy: 0.7771
# Epoch 13/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9079Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2243 - accuracy: 0.9079 - val_loss: 0.5806 - val_accuracy: 0.7684
# Epoch 14/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9094Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2152 - accuracy: 0.9094 - val_loss: 0.5501 - val_accuracy: 0.7684
# Epoch 15/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9090Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 363s 2s/step - loss: 0.2160 - accuracy: 0.9090 - val_loss: 0.5803 - val_accuracy: 0.7790
# Epoch 16/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9079Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2189 - accuracy: 0.9079 - val_loss: 0.5677 - val_accuracy: 0.7645
# Epoch 17/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9111Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2156 - accuracy: 0.9111 - val_loss: 0.5111 - val_accuracy: 0.7689
# Epoch 18/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9121Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 363s 2s/step - loss: 0.2203 - accuracy: 0.9121 - val_loss: 0.5466 - val_accuracy: 0.7495
# Epoch 19/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9025Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 367s 2s/step - loss: 0.2193 - accuracy: 0.9025 - val_loss: 0.5229 - val_accuracy: 0.7664
# Epoch 20/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9142Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_01-val_loss_0.8150.h5 (val: 0.8150)
# 151/151 [==============================] - 367s 2s/step - loss: 0.2074 - accuracy: 0.9142 - val_loss: 0.5627 - val_accuracy: 0.7771
# Epoch 21/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9102Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_04-val_loss_0.6692.h5 (val: 0.6692)
# 151/151 [==============================] - 368s 2s/step - loss: 0.2183 - accuracy: 0.9102 - val_loss: 0.5374 - val_accuracy: 0.7732
# Epoch 22/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9167Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_05-val_loss_0.6256.h5 (val: 0.6256)
# 151/151 [==============================] - 366s 2s/step - loss: 0.2072 - accuracy: 0.9167 - val_loss: 0.5636 - val_accuracy: 0.7718
# Epoch 23/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9142Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_03-val_loss_0.5981.h5 (val: 0.5981)
# 151/151 [==============================] - 365s 2s/step - loss: 0.2057 - accuracy: 0.9142 - val_loss: 0.5223 - val_accuracy: 0.7539
# Epoch 24/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9142Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_24-val_loss_0.5972.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_24-val_loss_0.5972.h5 (val: 0.5972)
# 151/151 [==============================] - 368s 2s/step - loss: 0.2056 - accuracy: 0.9142 - val_loss: 0.5972 - val_accuracy: 0.7640
# Epoch 25/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9177Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_02-val_loss_0.5823.h5 (val: 0.5823)
# 151/151 [==============================] - 369s 2s/step - loss: 0.2035 - accuracy: 0.9177 - val_loss: 0.5396 - val_accuracy: 0.7669
# Epoch 26/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9163Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_13-val_loss_0.5806.h5 (val: 0.5806)
# 151/151 [==============================] - 367s 2s/step - loss: 0.2032 - accuracy: 0.9163 - val_loss: 0.5628 - val_accuracy: 0.7732
# Epoch 27/50
# 151/151 [==============================] - 367s 2s/step - loss: 0.1991 - accuracy: 0.9152 - val_loss: 0.6278 - val_accuracy: 0.7602
# Epoch 28/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9154Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_15-val_loss_0.5803.h5 (val: 0.5803)
# 151/151 [==============================] - 365s 2s/step - loss: 0.2025 - accuracy: 0.9154 - val_loss: 0.5337 - val_accuracy: 0.7698
# Epoch 29/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9173Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_06-val_loss_0.5797.h5 (val: 0.5797)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2049 - accuracy: 0.9173 - val_loss: 0.4869 - val_accuracy: 0.7790
# Epoch 30/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9148Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_07-val_loss_0.5753.h5 (val: 0.5753)
# 151/151 [==============================] - 364s 2s/step - loss: 0.2006 - accuracy: 0.9148 - val_loss: 0.5145 - val_accuracy: 0.7747
# Epoch 31/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9165Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_22-val_loss_0.5636.h5 (val: 0.5636)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_16-val_loss_0.5677.h5 (val: 0.5677)
# 151/151 [==============================] - 364s 2s/step - loss: 0.1937 - accuracy: 0.9165 - val_loss: 0.5359 - val_accuracy: 0.7751
# Epoch 32/50
# 151/151 [==============================] - 365s 2s/step - loss: 0.2018 - accuracy: 0.9173 - val_loss: 0.6070 - val_accuracy: 0.7606
# Epoch 33/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9167Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
# ...
# Epoch 36/50
# 151/151 [==============================] - 364s 2s/step - loss: 0.1861 - accuracy: 0.9171 - val_loss: 0.5820 - val_accuracy: 0.7660
# Epoch 37/50
# 151/151 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9152Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_26-val_loss_0.5628.h5 (val: 0.5628)
# 151/151 [==============================] - 373s 2s/step - loss: 0.2021 - accuracy: 0.9152 - val_loss: 0.5412 - val_accuracy: 0.8008
# Epoch 38/50
# 151/151 [==============================] - 388s 3s/step - loss: 0.1909 - accuracy: 0.9212 - val_loss: 0.6217 - val_accuracy: 0.7756
# Epoch 39/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9152Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_20-val_loss_0.5627.h5 (val: 0.5627)
# 151/151 [==============================] - 389s 3s/step - loss: 0.1923 - accuracy: 0.9152 - val_loss: 0.4940 - val_accuracy: 0.7529
# Epoch 40/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9167Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5 (val: 0.5369)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_10-val_loss_0.5617.h5 (val: 0.5617)
# 151/151 [==============================] - 368s 2s/step - loss: 0.1937 - accuracy: 0.9167 - val_loss: 0.5369 - val_accuracy: 0.7732
# Epoch 41/50
# 151/151 [==============================] - 364s 2s/step - loss: 0.1928 - accuracy: 0.9148 - val_loss: 0.6000 - val_accuracy: 0.7790
# Epoch 42/50
# 151/151 [==============================] - 364s 2s/step - loss: 0.1934 - accuracy: 0.9196 - val_loss: 0.5680 - val_accuracy: 0.7824
# Epoch 43/50
# 151/151 [==============================] - 367s 2s/step - loss: 0.1866 - accuracy: 0.9185 - val_loss: 0.6792 - val_accuracy: 0.7635
# Epoch 44/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9200Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_44-val_loss_0.5421.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5 (val: 0.5369)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_44-val_loss_0.5421.h5 (val: 0.5421)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_14-val_loss_0.5501.h5 (val: 0.5501)
# 151/151 [==============================] - 366s 2s/step - loss: 0.1859 - accuracy: 0.9200 - val_loss: 0.5421 - val_accuracy: 0.7809
# Epoch 45/50
# 151/151 [==============================] - 365s 2s/step - loss: 0.1856 - accuracy: 0.9202 - val_loss: 0.6787 - val_accuracy: 0.7713
# Epoch 46/50
# 151/151 [==============================] - 365s 2s/step - loss: 0.1998 - accuracy: 0.9144 - val_loss: 0.6401 - val_accuracy: 0.7679
# Epoch 47/50
# 151/151 [==============================] - 367s 2s/step - loss: 0.1952 - accuracy: 0.9163 - val_loss: 0.5700 - val_accuracy: 0.7693
# Epoch 48/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9135Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_48-val_loss_0.4950.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_48-val_loss_0.4950.h5 (val: 0.4950)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5 (val: 0.5369)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_44-val_loss_0.5421.h5 (val: 0.5421)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_18-val_loss_0.5466.h5 (val: 0.5466)
# 151/151 [==============================] - 368s 2s/step - loss: 0.1956 - accuracy: 0.9135 - val_loss: 0.4950 - val_accuracy: 0.7877
# Epoch 49/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9169Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_49-val_loss_0.4737.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_49-val_loss_0.4737.h5 (val: 0.4737)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_48-val_loss_0.4950.h5 (val: 0.4950)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5 (val: 0.5369)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_44-val_loss_0.5421.h5 (val: 0.5421)
# 151/151 [==============================] - 364s 2s/step - loss: 0.1853 - accuracy: 0.9169 - val_loss: 0.4737 - val_accuracy: 0.7921
# Epoch 50/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1908 - accuracy: 0.9175Model saved to C:\Users\ksaks\Downloads\DATA\Models\model_epoch_50-val_loss_0.4687.h5. Current top 20 models:
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_50-val_loss_0.4687.h5 (val: 0.4687)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_49-val_loss_0.4737.h5 (val: 0.4737)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_29-val_loss_0.4869.h5 (val: 0.4869)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_39-val_loss_0.4940.h5 (val: 0.4940)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_48-val_loss_0.4950.h5 (val: 0.4950)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_17-val_loss_0.5111.h5 (val: 0.5111)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_30-val_loss_0.5145.h5 (val: 0.5145)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_12-val_loss_0.5177.h5 (val: 0.5177)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_23-val_loss_0.5223.h5 (val: 0.5223)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_19-val_loss_0.5229.h5 (val: 0.5229)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_08-val_loss_0.5299.h5 (val: 0.5299)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_28-val_loss_0.5337.h5 (val: 0.5337)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_09-val_loss_0.5340.h5 (val: 0.5340)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_33-val_loss_0.5348.h5 (val: 0.5348)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_31-val_loss_0.5359.h5 (val: 0.5359)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_40-val_loss_0.5369.h5 (val: 0.5369)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_21-val_loss_0.5374.h5 (val: 0.5374)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_25-val_loss_0.5396.h5 (val: 0.5396)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_11-val_loss_0.5401.h5 (val: 0.5401)
#   - C:\Users\ksaks\Downloads\DATA\Models\model_epoch_37-val_loss_0.5412.h5 (val: 0.5412)
# 151/151 [==============================] - 369s 2s/step - loss: 0.1908 - accuracy: 0.9175 - val_loss: 0.4687 - val_accuracy: 0.7790

# %%
model.save('C:/Users/ksaks/Downloads/DATA/Models/lasr_model_VGG.h5')
